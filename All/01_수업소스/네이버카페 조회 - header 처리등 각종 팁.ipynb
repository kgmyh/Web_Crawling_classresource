# %%
import requests

# %% [markdown]
# # User-agent  가 필요한 사이트
# - **웹브라우저에서는 접속이 되는데 Python에서는 안되는 경우** User-Agent 항목을 추가한다.
# - 웹브라우저 User-Agent 검색
#     - 구글에서 `my user agent` 로 검색

# %%
url = 'https://onoffmix.com'
res = requests.get(url)
res.status_code
# Out:
# 500

# %%
res.text
# Out:
# '<html>\r\n<head><title>500 Internal Server Error</title></head>\r\n<body bgcolor="white">\r\n<center><h1>500 Internal Server Error</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
ua = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'
res = requests.get(url, headers={'User-Agent':ua})
res.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup
import re

# p = re.compile('[\s\u200b]+')
# txt = p.sub(' ', res.text)
# bs = BeautifulSoup(txt, 'lxml')

bs = BeautifulSoup(res.text, 'lxml')
html_doc = bs.prettify()
print(html_doc)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={xpid:"VgcEUlRbDhABVVhbDwIHV1w="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(18),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(19),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var x=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof x&&(this.bstStart=g.now())}),o.on(w,function(t,n){var e=t[0];e instanceof x&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(w,function(t,n){i(v,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(21)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o= ...
#   </script>
#   <meta content="onoffmix, event, 온오프믹스, 모임, 행사, 번개, 이벤트" name="keywords"/>
#   <meta content="세상의 모든 모임 '온오프믹스'" name="description"/>
#   <meta content="ONOFFMIX Inc. (webmaster@onoffmix.com)" name="author"/>
#   <meta content="width=1280" name="viewport"/>
#   <title>
#    온오프믹스 :: 모임문화 플랫폼
#   </title>
#   <link href="https://static.onoffmix.com/images/pc/icon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!--
#         =================================== 공통 시작 ===================================  -->
#   <!-- OFM Common Style -->
#   <link href="https://static.onoffmix.com/css/common/pc/common-pc.css" rel="stylesheet"/>
#   <!-- Common Script -->
#   <script src="https://static.onoffmix.com/js/pc/dist/common/plugins/jquery-1.10.2.js">
#   </script>
#   <script src="https://static.onoffmix.com/js/pc/dist/common/plugins/jquery-ui-1.10.4.custom.js">
#   </script>
#   <script src="https://static.onoffmix.com/js/pc/dist/common/plugins/jquery.dotdotdot-1.5.0.js">
#   </script>
#   <!--[if lt IE 9]>
#         <script src="https://static.onoffmix.com/js/pc/dist/common/plugins/html5shiv.min.js"></script>
#         <script src="https://static.onoffmix.com/js/pc/dist/common/reponse.ie8.js"></script>
#     <![endif]-->
#   <!-- =================================== 공통 끝 ===================================  -->
#   <!-- =================================== 화면 고유 시작 ===================================  -->
#   <!-- OFM Style -->
#   <link href="https://static.onoffmix.com/css/pc/main/new-main.css" rel="stylesheet"/>
#   <!-- =================================== 화면 고유 끝 ===================================  -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-TMSKZ8" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 			new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 			j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 			'//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-TMSKZ8');
#   </script>
#  </head>
#  <body class="onoffmix">
#   <!-- =================================== Header Start =================================== -->
#   <header class="header_wrap" id="header">
#    <div class="header_top wide_max_width_area">
#     <h1 class="ofm_logo">
#      <a href="/">
#       <span class="text_logo">
#        온오프믹스 홈
#       </span>
#       <img alt="ONOFFMIX" src="https://static.onoffmix.com/images/pc/ofm_logo.png"/>
#      </a>
#     </h1>
#     <div class="user_area">
#      <ul class="service_menu">
#       <li class="list_item">
#        <a href="/account/login">
#         로그인
#        </a>
#       </li>
#       <li class="list_item">
#        <a href="/account/join">
#         회원가입
#        </a>
#       </li>
#       <li class="list_item">
#        <a href="/service">
#         서비스안내
#        </a>
#       </li>
#       <li class="list_item">
#        <a href="/cs/main">
#         고객센터
#        </a>
#       </li>
#      </ul>
#      <ul class="member_menu">
#       <li class="list_item mypage" tabindex="0">
#        <a href="/account/main">
#         마이페이지
#        </a>
#        <div class="sub_menu">
#         <ul class="sub_list mypage_list">
#          <li>
#           <a class="site_link edit" href="/account/login?returnUrl=/account/edit">
#            회원정보수정
#           </a>
#          </li>
#          <li>
#           <a class="site_link pass" href="/account/login?returnUrl=/account/pass">
#            비밀번호변경
#           </a>
#          </li>
#          <li>
#           <a class="site_link event" href="/account/login?returnUrl=/account/event">
#            신청내역
#           </a>
#          </li>
#          <li>
#           <a class="site_link payment" href="/account/login?returnUrl=/account/payment">
#            결제내역
#           </a>
#          </li>
#          <li>
#           <a class="site_link pin" href="/account/login?returnUrl=/account/pin">
#            찜내역
#           </a>
#          </li>
#         </ul>
#        </div>
#       </li>
#       <li class="list_item eventopen">
#        <a href="/event/add">
#         모임개설
#        </a>
#       </li>
#       <li class="list_item manage">
#        <a href="/account/login?returnUrl=/event/manage">
#         모임관리
#        </a>
#       </li>
#       <li class="list_item notice">
#        <a href="/account/login?returnUrl=/">
#         알림
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="search_area">
#      <form action="/event/main" class="search_form" method="GET">
#       <label for="searchInput">
#        검색할 모임을 입력해주세요.
#       </label>
#       <input class="search_input" data-event="184436" id="searchInput" name="s" title="키워드로 모임을 검색하세요" type="text" value=""/>
#       <span class="ofm_keyword_value">
#        경기도 온라인 강사되기 프로젝트 →
#       </span>
#       <input class="btn_search" title="검색" type="submit" value="검색"/>
#      </form>
#     </div>
#    </div>
#    <div class="header_bottom">
#     <div class="wide_max_width_area">
#      <div class="category_section">
#       <div class="title_wrap">
#        <button class="btn_category">
#         카테고리
#        </button>
#       </div>
#      </div>
#     </div>
#     <div class="detail_category">
#      <div class="wide_max_width_area">
#       <!-- 모임 -->
#       <section class="category_event">
#        <h1>
#         모임
#        </h1>
#        <ul class="list_col">
#         <li class="list_item">
#          <a href="/event/main/?c=085">
#           교육
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=086">
#           강연
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=087">
#           세미나/컨퍼런스
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=088">
#           문화/예술
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=089">
#           방송/연예
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=090">
#           취미활동
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=091">
#           소모임/친목행사
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=092">
#           공모전
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=093">
#           전시/박람회
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=094">
#           패션/뷰티
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=095">
#           이벤트/파티
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=097">
#           여행
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=023">
#           후원금
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?c=096">
#           기타
#          </a>
#         </li>
#        </ul>
#       </section>
#       <!-- 지역 -->
#       <section class="category_area">
#        <h1>
#         지역
#        </h1>
#        <ul class="list_col">
#         <li class="list_item">
#          <a href="/event/main/?region=02">
#           서울
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=032,031">
#           인천/경기
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=042,043,041,044">
#           대전/충청/세종
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=051,052,054">
#           부산/울산/경남
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=062,063,061">
#           광주/전라
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=053,055">
#           대구/경북
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=033">
#           강원
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=064">
#           제주
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?region=00">
#           기타지역
#          </a>
#         </li>
#        </ul>
#       </section>
#       <!-- 시간/요일 -->
#       <section class="category_time">
#        <h1>
#         시간/비용
#        </h1>
#        <ul class="list_col">
#         <li class="list_item">
#          <a href="/event/main/?timespan=6-11">
#           오전
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?timespan=12-17">
#           오후
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?weekday=0,1,2,3,4">
#           주중
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?weekday=5,6">
#           주말
#          </a>
#         </li>
#        </ul>
#        <ul class="list_col">
#         <li class="list_item">
#          <a href="/event/main/?isfree=Y">
#           무료
#          </a>
#         </li>
#         <li class="list_item">
#          <a href="/event/main/?isfree=N">
#           유료
#          </a>
#         </li>
#        </ul>
#       </section>
#      </div>
#      <div class="category_action_area">
#       <div class="wide_max_width_area">
#        <a class="btn_all_event" href="/event/main">
#         전체 모임 보기
#         <span>
#          &gt;
#         </span>
#        </a>
#        <button class="btn_close">
#         <span>
#          카테고리 닫기
#         </span>
#         <img alt="닫기" src="https://static.onoffmix.com/images/pc/svg/category_close_blue.svg"/>
#        </button>
#       </div>
#      </div>
#     </div>
#     <div class="wide_max_width_area">
#      <div class="right_section">
#       <!-- link section -->
#       <div class="link_section">
#        <a class="link_item" data-c="b09b92011" href="/prom/best">
#         베스트
#        </a>
#        <a class="link_item" data-c="b09b92021" href="/prom/invitation">
#         이벤트
#        </a>
#        <a class="link_item" data-c="b09b92031" href="/prom/exhibition">
#         기획전
#        </a>
#        <a class="link_item place" data-c="b09b92041" href="https://place.onoffmix.com" target="_blank">
#         <span>
#          플레이스
#         </span>
#         <span class="text_bold text_spacing-0">
#          GO
#         </span>
#        </a>
#       </div>
#       <!-- lanking event -->
#       <div class="event_ranking">
#        <div class="visible_lanking">
#         <span class="ranking_number">
#         </span>
#         <span class="event_title">
#         </span>
#        </div>
#        <div class="detail_ranking_area">
#         <h2>
#          실시간
#          <span class="date_time">
#           2019.6.27
#          </span>
#         </h2>
#         <ol class="ranking_list">
#          <li class="visible">
#           <a href="/event/184852" title="제13회 블록체인 TechBiz 컨퍼런스">
#            <span class="ranking_number">
#             1
#            </span>
#            <span class="event_title">
#             제13회 블록체인 TechBiz 컨퍼런스
#            </span>
#            <span class="ranking_status up">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/183626" title="2019 KOTRA 신입사원 채용설명회">
#            <span class="ranking_number">
#             2
#            </span>
#            <span class="event_title">
#             2019 KOTRA 신입사원 채용설명회
#            </span>
#            <span class="ranking_status up">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/181736" title="2019 AI 페스티벌">
#            <span class="ranking_number">
#             3
#            </span>
#            <span class="event_title">
#             2019 AI 페스티벌
#            </span>
#            <span class="ranking_status up">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/185252" title="FABRK 밋업에 초대합니다 (다과, 음료 무료제공)">
#            <span class="ranking_number">
#             4
#            </span>
#            <span class="event_title">
#             FABRK 밋업에 초대합니다 (다과, 음료 무료제공)
#            </span>
#            <span class="ranking_status new">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/184809" title='[초대이벤트] 7월 달에도! 연극 "오! 나의 귀신님"'>
#            <span class="ranking_number">
#             5
#            </span>
#            <span class="event_title">
#             [초대이벤트] 7월 달에도! 연극 "오! 나의 귀신님"
#            </span>
#            <span class="ranking_status new">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/183625" title="[스타트업캠퍼스] 7-8월 수요 인문학 콘서트(CEO Special Stage)">
#            <span class="ranking_number">
#             6
#            </span>
#            <span class="event_title">
#             [스타트업캠퍼스] 7-8월 수요 인문학 콘서트(CEO Special Stage)
#            </span>
#            <span class="ranking_status down">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/184987" title="대한민국 혁신성장, 데이터 고속도로 청사진">
#            <span class="ranking_number">
#             7
#            </span>
#            <span class="event_title">
#             대한민국 혁신성장, 데이터 고속도로 청사진
#            </span>
#            <span class="ranking_status new">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/185029" title="[TOAST FORWARD] 하루에 정리하는 Spring Framework Core">
#            <span class="ranking_number">
#             8
#            </span>
#            <span class="event_title">
#             [TOAST FORWARD] 하루에 정리하는 Spring Framework Core
#            </span>
#            <span class="ranking_status new">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/185036" title="인물화를 위한 얼굴 그리기 기초 원데이클래스(홍대)">
#            <span class="ranking_number">
#             9
#            </span>
#            <span class="event_title">
#             인물화를 위한 얼굴 그리기 기초 원데이클래스(홍대)
#            </span>
#            <span class="ranking_status new">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="/event/185000" title="2019년 공공데이터 품질관리 기본교육(7월 12일, 서울)">
#            <span class="ranking_number">
#             10
#            </span>
#            <span class="event_title">
#             2019년 공공데이터 품질관리 기본교육(7월 12일, 서울)
#            </span>
#            <span class="ranking_status new">
#             새로운 순위
#            </span>
#           </a>
#          </li>
#         </ol>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- =================================== Main Start =================================== -->
#     <main class="main" id="content">
#      <!-- =================================== 최근본기록 Start =================================== -->
#      <div class="today_seen_menu">
#       <div class="wing_position">
#        <section class="today_seen">
#         <div class="title_area">
#          <h1 class="title">
#           최근 본 모임
#          </h1>
#         </div>
#         <p class="none_list">
#          최근 본 모임이
#          <br/>
#          없습니다.
#         </p>
#         <ul class="today_list">
#         </ul>
#         <!-- 모임리스트가 없을경우 .paging_area > * 안에 요소들 모두 none처리됨 -->
#         <div class="paging_area">
#         </div>
#        </section>
#       </div>
#      </div>
#      <!-- =================================== 최근본기록 End =================================== -->
#      <!-- Tap silder -->
#      <section class="section_main_banner slider-rotate">
#       <!-- 최소/최대 5구좌 -->
#       <div class="banner_main slider-rotate__container">
#        <a class="item slider-rotate__item" data-c="9db3fb7e1" href="/cs/a/44604?url=%2Fevent%2F184073" target="_blank" title="2019년도 『테스트베드 서울』 실증지원 사업 공고">
#         <img alt="2019년도 『테스트베드 서울』 실증지원 사업 공고" src="https://cfile1.onoffmix.com/attach/NLXhkvUVFPgCzOtJ97EHxDBlj4Sapw8q"/>
#        </a>
#        <a class="item slider-rotate__item" data-c="9db3fb7e2" href="/cs/a/44640?url=%2Fevent%2F184134" target="_blank" title="LG유플러스와 함께하는 구글 클라우드 플랫폼 교육 참가 모집 (7/8, 7/16)">
#         <img alt="LG유플러스와 함께하는 구글 클라우드 플랫폼 교육 참가 모집 (7/8, 7/16)" src="https://cfile1.onoffmix.com/attach/nSTs2wkL0C5jBZPFRlOUKeqWodEIhYvr"/>
#        </a>
#        <a class="item slider-rotate__item" data-c="9db3fb7e3" href="/cs/a/44716?url=%2Fevent%2F183418" target="_blank" title="2019 Akamai Security Summit Seoul">
#         <img alt="2019 Akamai Security Summit Seoul" src="https://cfile1.onoffmix.com/attach/1QI39cZqUS6alYT5rmWvHDXEGu7onCpf"/>
#        </a>
#        <a class="item slider-rotate__item" data-c="9db3fb7e4" href="/cs/a/44720?url=%2Fevent%2F184133" target="_blank" title="2019 Traders Marketing Course [무역전문가 양성교육]">
#         <img alt="2019 Traders Marketing Course [무역전문가 양성교육]" src="https://cfile1.onoffmix.com/attach/vqBQy2DldfmIYw7RLCgbE6XZizAnWeGT"/>
#        </a>
#        <a class="item slider-rotate__item" data-c="9db3fb7e5" href="/cs/a/44378?url=%2Fevent%2F181897" target="_blank" title="박관식 대표의 5천만원으로 10억 만드는 비법">
#         <img alt="박관식 대표의 5천만원으로 10억 만드는 비법" src="https://cfile1.onoffmix.com/attach/VwfkxybHGSvt35CRDO10FlAEKNJs7jad"/>
#        </a>
#       </div>
#       <div class="slider-rotate__nav">
#        <span class="slider-rotate__arrow slider-rotate__arrow--right js-slider-rotate-arrow" data-action="next">
#         &gt;
#        </span>
#        <span class="slider-rotate__arrow slider-rotate__arrow--left js-slider-rotate-arrow" data-action="prev">
#         &lt;
#        </span>
#       </div>
#      </section>
#      <!-- marketing / text silder-->
#      <section class="section_main_top">
#       <div class="content_wrap wide_max_width_area">
#        <div class="banner_branding owl-carousel">
#         <a data-c="777143e61" href="/cs/a/45157?url=%2Fevent%2F185186" target="_blank" title="[기방도령] 온오프믹스 특별초대 시사회">
#          <img alt="[기방도령] 온오프믹스 특별초대 시사회" src="https://cfile1.onoffmix.com/attach/96LymWcG04Q1TE5OMKbX7tiCSHs8UAhR"/>
#         </a>
#         <a data-c="777143e62" href="/cs/a/44837?url=%2Fevent%2F183940" target="_blank" title="[난폭한 기록] 온오프믹스 예매권 이벤트">
#          <img alt="[난폭한 기록] 온오프믹스 예매권 이벤트" src="https://cfile1.onoffmix.com/attach/tPx1l5MBD4rJWenHKLv2bAQ97FUYV6Rp"/>
#         </a>
#         <a data-c="777143e63" href="/cs/a/45025?url=%2Fevent%2F184343" target="_blank" title="[댕퍼런스] 온오프믹스 특별초대 컨퍼런스">
#          <img alt="[댕퍼런스] 온오프믹스 특별초대 컨퍼런스" src="https://cfile1.onoffmix.com/attach/b0gyXPTiJpC6VAnHIq4MfDvQLdk9BUwN"/>
#         </a>
#         <a data-c="777143e64" href="/cs/a/23201?url=https%3A%2F%2Fwww.youtube.com%2Fchannel%2FUC2W4gjEfJBaEheQ1vwACVTg%2Fvideos" target="_blank" title="볼거리가 가득한 온오프믹스 유튜브채널! #좋아요 #구독 ">
#          <img alt="볼거리가 가득한 온오프믹스 유튜브채널! #좋아요 #구독 " src="https://cfile1.onoffmix.com/attach/qm7OKu45YyEki0xfvSMtebRjDNPLgW8H"/>
#         </a>
#         <a data-c="777143e65" href="/cs/a/42226?url=https%3A%2F%2Fblog.naver.com%2Fonoffmix" target="_blank" title="온오프믹스 블로그">
#          <img alt="온오프믹스 블로그" src="https://cfile1.onoffmix.com/attach/wEyF1epck7fYsb8gBxDjVXtI23AvlUTZ"/>
#         </a>
#        </div>
#        <div class="banner_top_area">
#         <!-- 최소/최대 8구좌 -->
#         <ul class="title_list_area">
#         </ul>
#         <ul class="banner_text">
#          <li>
#           <a data-c="aa16fe1a1" href="/cs/a/44759?url=%2Fevent%2F184238" target="_blank" title="2019 교원 DEEP CHANGE 스타트업 프라이즈">
#            <img alt="2019 교원 DEEP CHANGE 스타트업 프라이즈" src="https://cfile1.onoffmix.com/attach/mKro364UyjZXR0SCBQTkLFMcnWOwH7v2"/>
#           </a>
#          </li>
#          <li>
#           <a data-c="aa16fe1a2" href="/cs/a/44227?url=%2Fevent%2F181177" target="_blank" title="2019 업비트 개발자 컨퍼런스(Upbit Developer Conference)">
#            <img alt="2019 업비트 개발자 컨퍼런스(Upbit Developer Conference)" src="https://cfile1.onoffmix.com/attach/dYKFwGQ7HR9ysUbgOJM8tnXABfiaEPuW"/>
#           </a>
#          </li>
#          <li>
#           <a data-c="aa16fe1a3" href="/cs/a/44451?url=%2Fevent%2F183625" target="_blank" title="[스타트업캠퍼스] 7-8월 수요 인문학 콘서트(CEO Special Stage)">
#            <img alt="[스타트업캠퍼스] 7-8월 수요 인문학 콘서트(CEO Special Stage)" src="https://cfile1.onoffmix.com/attach/M7ielfkbBRXOaomzFuIpjHADrVWtTS52"/>
#           </a>
#          </li>
#          <li>
#           <a data-c="aa16fe1a4" href="/cs/a/44938?url=%2Fevent%2F184349" target="_blank" title="2019 Invest KOREA 포럼">
#            <img alt="2019 Invest KOREA 포럼" src="https://cfile1.onoffmix.com/attach/l47YP16pUwsg8ANRQTxVvhHinmDSfoM9"/>
#           </a>
#          </li>
#          <li>
#           <a data-c="aa16fe1a5" href="/cs/a/44980?url=%2Fevent%2F184877" target="_blank" title="SBA 인사 네트워크 세미나 'HR TOK'">
#            <img alt="SBA 인사 네트워크 세미나 'HR TOK'" src="https://cfile1.onoffmix.com/attach/Yyd4z25Tuhf3sIgRUZSBGlA0kjWrPm7c"/>
#           </a>
#          </li>
#          <li>
#           <a data-c="aa16fe1a6" href="/cs/a/44509?url=%2Fevent%2F183037" target="_blank" title="SK텔레콤과 함께, 5G의 가치를 더할 스타트업을 찾습니다">
#            <img alt="SK텔레콤과 함께, 5G의 가치를 더할 스타트업을 찾습니다" src="https://cfile1.onoffmix.com/attach/gcDLfiK4JGxNlh1OVWIHdpjsrS6YaP8o"/>
#           </a>
#          </li>
#          <li>
#           <a data-c="aa16fe1a7" href="/cs/a/43789?url=%2Fevent%2F179927" target="_blank" title="2019년 좋은 일터 기업 콘텐츠 공모전">
#            <img alt="2019년 좋은 일터 기업 콘텐츠 공모전" src="https://cfile1.onoffmix.com/attach/D9R0sAJZBTpmCQWiVwPbl5YNEc3UGXMd"/>
#           </a>
#          </li>
#          <li>
#           <a data-c="aa16fe1a8" href="/cs/a/44853?url=%2Fevent%2F184061" target="_blank" title="2019 전문 액셀러레이터 제1기 양성 교육">
#            <img alt="2019 전문 액셀러레이터 제1기 양성 교육" src="https://cfile1.onoffmix.com/attach/ViqmXyjxLQsBo94eZwGd86nJMI5vgkOK"/>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <!-- Right Now Event -->
#        <section class="section_now_event">
#         <div class="title_area">
#          <h1 class="title">
#           지금 딱!
#           <span class="text_normal">
#            이 모임
#           </span>
#          </h1>
#         </div>
#         <div class="content_wrap wide_max_width_area">
#          <div class="area_top">
#           <ul class="event_list">
#            <li>
#             <article class="event_area event_card">
#              <a data-c="hotissue1" href="/cs/a/44955?url=%2Fevent%2F183959" target="_blank" title="(7월) 월간 강연콘서트 &lt;김창옥TV SHOW&gt;">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/183959/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  (7월) 월간 강연콘서트 &lt;김창옥TV SHOW&gt;
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type pay">
#                   유료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.20 (토)
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="hotissue2" href="/cs/a/44873?url=%2Fevent%2F184416" target="_blank" title="세무회계사무원">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/184416/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  세무회계사무원
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.1 ~ 9.25
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="hotissue3" href="/cs/a/45088?url=%2Fevent%2F183288" target="_blank" title="[전국대회] 제4회 부산 ICT융합 해카톤 대회">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/183288/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  [전국대회] 제4회 부산 ICT융합 해카톤 대회
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type pay">
#                   유료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.24 ~ 7.26
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="hotissue4" href="/cs/a/44876?url=%2Fevent%2F183915" target="_blank" title="[62기] 웹 개발자의 생존전략! 판도라의 상자를 엽니다(피자제공) 7/7(일)">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/183915/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  [62기] 웹 개발자의 생존전략! 판도라의 상자를 엽니다(피자제공) 7/7(일)
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type pay">
#                   유료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.7 (일)
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="hotissue5" href="/cs/a/44972?url=%2Fevent%2F183862" target="_blank" title="상장예정기업투자 정규 입문특강 ★ 20배 수익 나는 기업 찾는법 ★">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/attach/aLwXn8jpeJBVoYOIMtgZq4r2dP9mlv6E"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  상장예정기업투자 정규 입문특강 ★ 20배 수익 나는 기업 찾는법 ★
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type pay">
#                   유료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.4 ~ 7.6
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="hotissue6" href="/cs/a/45082?url=%2Fevent%2F185121" target="_blank" title="2019년 경기 콘텐츠코리아 랩 위키팩처링 캠프 참가팀 모집">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/185121/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  2019년 경기 콘텐츠코리아 랩 위키팩처링 캠프 참가팀 모집
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  8.1 ~ 12.31
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#           </ul>
#           <!-- 최소1구좌, 최대3구좌 -->
#           <div class="banner_now_top owl-carousel">
#            <a data-c="559c659b1" href="/cs/a/44934?url=%2Fevent%2F184334" target="_blank" title="2019년 제4회 빅데이터 신산업 스타트업 콘테스트">
#             <img alt="2019년 제4회 빅데이터 신산업 스타트업 콘테스트" src="https://cfile1.onoffmix.com/attach/BHjAdgGusYPzk4JD3Q1KC2XRZNUqfo0V"/>
#            </a>
#            <a data-c="559c659b2" href="/cs/a/45120?url=%2Fevent%2F182468" target="_blank" title="2019&lt;예술 해커톤 : 아트센터 고객서비스&gt;">
#             <img alt="2019&lt;예술 해커톤 : 아트센터 고객서비스&gt;" src="https://cfile1.onoffmix.com/attach/bMVvNzhWoTY4uR3DF8B0tma6CLIlnjyi"/>
#            </a>
#            <a data-c="559c659b3" href="/cs/a/45164?url=%2Fevent%2F184436" target="_blank" title="경기도 온라인 강사되기 프로젝트">
#             <img alt="경기도 온라인 강사되기 프로젝트" src="https://cfile1.onoffmix.com/attach/WP8wJyFYragBZXhkmbdRelKtTqE4MUVD"/>
#            </a>
#           </div>
#          </div>
#          <div class="area_bottom">
#           <ul class="event_list">
#            <li>
#             <article class="event_area event_card">
#              <a data-c="f7ae469a1" href="/cs/a/45161?url=%2Fevent%2F185188" target="_blank" title="[서울창업허브] 메이커 및 예비창업자를 위한 창업기초교육 프로그램 참가자 모집">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/185188/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  [서울창업허브] 메이커 및 예비창업자를 위한 창업기초교육 프로그램 참가자 모집
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.5 (금)
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="f7ae469a2" href="/cs/a/45030?url=%2Fevent%2F183325" target="_blank" title="해외구매대행의 모든것, 글로벌 오픈마켓을 활용한 재창업과정">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/183325/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  해외구매대행의 모든것, 글로벌 오픈마켓을 활용한 재창업과정
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.8 ~ 7.25
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="f7ae469a3" href="/cs/a/44883?url=%2Fevent%2F184436" target="_blank" title="경기도 온라인 강사되기 프로젝트">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/184436/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  경기도 온라인 강사되기 프로젝트
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.4 (목)
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="f7ae469a4" href="/cs/a/45004?url=%2Fevent%2F184349" target="_blank" title="2019 Invest KOREA 포럼">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/184349/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  2019 Invest KOREA 포럼
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.3 (수)
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="f7ae469a5" href="/cs/a/44795?url=%2Fevent%2F181897" target="_blank" title="박관식 대표의 5천만원으로 10억 만드는 비법">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/181897/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  박관식 대표의 5천만원으로 10억 만드는 비법
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.1 ~ 7.3
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#            <li>
#             <article class="event_area event_card">
#              <a data-c="f7ae469a6" href="/cs/a/45174?url=%2Fevent%2F183625" target="_blank" title="[스타트업캠퍼스] 7-8월 수요 인문학 콘서트(CEO Special Stage)">
#               <!-- 이미지 -->
#               <div class="event_thumbnail">
#                <img src="https://cfile1.onoffmix.com/images/event/183625/s"/>
#               </div>
#               <div class="event_info_area">
#                <!-- 타이틀 -->
#                <div class="title_area">
#                 <h5 class="title ellipsis">
#                  [스타트업캠퍼스] 7-8월 수요 인문학 콘서트(CEO Special Stage)
#                 </h5>
#                </div>
#                <!-- 정보 -->
#                <div class="event_info">
#                 <div class="type_info">
#                  <span class="payment_type free">
#                   무료
#                  </span>
#                 </div>
#                 <div class="date">
#                  7.3 (수)
#                 </div>
#                </div>
#               </div>
#              </a>
#             </article>
#            </li>
#           </ul>
#           <!-- 최소1구좌, 최대3구좌 -->
#           <div class="banner_now_bottom owl-carousel">
#            <a data-c="adfab8f91" href="/cs/a/45125?url=%2Fevent%2F184468" target="_blank" title="다함께 게임문화TALK!!(서울)">
#             <img alt="다함께 게임문화TALK!!(서울)" src="https://cfile1.onoffmix.com/attach/UwLVupi1HJ9b3SBxgytZ6EDkPTAKd0Xo"/>
#            </a>
#            <a data-c="adfab8f92" href="/cs/a/45087?url=%2Fevent%2F184430" target="_blank" title="2019 부산국제광고제">
#             <img alt="2019 부산국제광고제" src="https://cfile1.onoffmix.com/attach/bTmqdBnhOrJtQ203Y1ok7iSEPXRexgHf"/>
#            </a>
#           </div>
#          </div>
#         </div>
#        </section>
#        <!-- Hot Issue -->
#        <!-- 최소/최대 5구좌 -->
#        <section class="section_hot_issue">
#         <div class="title_area">
#          <h1 class="title">
#           Hot
#           <span class="text_normal">
#            Issue
#           </span>
#          </h1>
#         </div>
#         <div class="content_wrap wide_max_width_area">
#          <div class="banner_hot_issue owl-carousel">
#           <a data-c="15dbd2791" href="/cs/a/45147?url=%2Fevent%2F170895" target="_blank" title='제 2회 한국국제전자담배박람회, "VAPE KOREA EXPO 2019"'>
#            <img alt='제 2회 한국국제전자담배박람회, "VAPE KOREA EXPO 2019"' src="https://cfile1.onoffmix.com/attach/e4qnIRHsXQUD9BCW1wSL0NYiu5pMjTFO"/>
#           </a>
#           <a data-c="15dbd2792" href="/cs/a/45009?url=%2Fevent%2F184910" target="_blank" title="2019년 실전창업교육 2기 교육생 모집">
#            <img alt="2019년 실전창업교육 2기 교육생 모집" src="https://cfile1.onoffmix.com/attach/jzvBKwUo7DT0trmZ4kp6hlsE3i1Cd2O8"/>
#           </a>
#           <a data-c="15dbd2793" href="/cs/a/45165?url=%2Fevent%2F178209" target="_blank" title="2019 코리아 뷰티 앤 코스메틱쇼(뷰티콘)">
#            <img alt="2019 코리아 뷰티 앤 코스메틱쇼(뷰티콘)" src="https://cfile1.onoffmix.com/attach/cadwE4sNjIhD0VernUio5kBM6Jq8ZAgT"/>
#           </a>
#           <a data-c="15dbd2794" href="/cs/a/45146?url=%2Fevent%2F184524" target="_blank" title="경기도 소재 디지털콘텐츠 기업을 위한 무료 법률자문 지원">
#            <img alt="경기도 소재 디지털콘텐츠 기업을 위한 무료 법률자문 지원" src="https://cfile1.onoffmix.com/attach/LDOrMbQqX8c05ed7oijfnFpsZS2lIa4B"/>
#           </a>
#           <a data-c="15dbd2795" href="/cs/a/44897?url=%2Fevent%2F184073" target="_blank" title="2019년도 『테스트베드 서울』 실증지원 사업 공고">
#            <img alt="2019년도 『테스트베드 서울』 실증지원 사업 공고" src="https://cfile1.onoffmix.com/attach/HzOS5tqLjWrgGMTb2p1UBXQoJaF6kN0f"/>
#           </a>
#          </div>
#         </div>
#        </section>
#        <!-- Today -->
#        <section class="section_today_event">
#         <div class="title_area">
#          <h1 class="title">
#           Today #
#          </h1>
#         </div>
#         <div class="content_wrap wide_max_width_area">
#          <div class="main_tags">
#           <a data-c="afc8f73f1" href="https://onoffmix.com/prom/invitation">
#            <p class="tag">
#             <span>
#              #무료초대
#             </span>
#            </p>
#            <img alt="#무료초대" src="https://cfile1.onoffmix.com/attach/q65bmLBiezA0FN9d8jvkJZOQRKlr2YCP"/>
#           </a>
#           <a data-c="afc8f73f2" href="https://onoffmix.com/event/main?s=%EB%B0%8B%EC%97%85">
#            <p class="tag">
#             <span>
#              #밋업
#             </span>
#            </p>
#            <img alt="#밋업" src="https://cfile1.onoffmix.com/attach/bUnrvRLfSAGHxY1zh9yoNF4eiZXgq7I2"/>
#           </a>
#           <a data-c="afc8f73f3" href="https://onoffmix.com/event/main?s=%EC%B0%BD%EC%97%85">
#            <p class="tag">
#             <span>
#              #창업
#             </span>
#            </p>
#            <img alt="#창업" src="https://cfile1.onoffmix.com/attach/1UqijertBzghDOGKIHxP5kY9WyFcC8Qf"/>
#           </a>
#          </div>
#          <ul class="tag_list">
#           <li>
#            <a data-c="a07090971" href="https://onoffmix.com/event/main?s=%EA%B0%95%EC%97%B0">
#             #강연
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090972" href="https://onoffmix.com/event/main?s=%EC%BD%98%ED%85%90%EC%B8%A0">
#             #콘텐츠
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090973" href="https://onoffmix.com/event/main?s=%ED%8A%B8%EB%A0%8C%EB%93%9C">
#             #트렌드
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090974" href="https://onoffmix.com/event/main?s=%ED%86%A0%ED%81%AC%EC%87%BC">
#             #토크쇼
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090975" href="https://onoffmix.com/event/main?s=3D">
#             #3D
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090976" href="http://www.onoffmix.com/event?s=%23%EC%95%84%EB%91%90%EC%9D%B4%EB%85%B8">
#             #아두이노
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090977" href="https://onoffmix.com/event/main?s=%EA%B5%90%EC%9C%A1">
#             #교육
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090978" href="https://www.onoffmix.com/event?s=%EC%B1%85%EC%93%B0%EA%B8%B0">
#             #책쓰기
#            </a>
#           </li>
#           <li>
#            <a data-c="a07090979" href="https://onoffmix.com/event/main?s=%EC%84%B8%EB%AF%B8%EB%82%98">
#             #세미나
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909710" href="https://onoffmix.com/event/main?s=%EB%AC%B4%EB%A3%8C">
#             #무료
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909711" href="https://onoffmix.com/event/main?s=%EB%A7%88%EC%BC%80%ED%8C%85">
#             #마케팅
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909712" href="https://onoffmix.com/event/main?s=%EA%B5%AD%EB%B9%84%EC%A7%80%EC%9B%90">
#             #국비지원
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909713" href="https://www.onoffmix.com/event/main?s=%EC%BB%A8%ED%8D%BC%EB%9F%B0%EC%8A%A4">
#             #컨퍼런스
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909714" href="https://onoffmix.com/event/main?s=%EC%98%81%ED%99%94">
#             #영화
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909715" href="https://onoffmix.com/event/main?s=%EC%9C%A0%ED%8A%9C%EB%B8%8C">
#             #유튜브
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909716" href="https://onoffmix.com/event/main?s=%EB%B9%84%ED%8A%B8%EC%BD%94%EC%9D%B8">
#             #비트코인
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909717" href="https://onoffmix.com/event/main?s=%EB%AC%B8%ED%99%94">
#             #문화
#            </a>
#           </li>
#           <li>
#            <a data-c="a070909718" href="https://onoffmix.com/event/main?s=%EC%9B%90%EB%8D%B0%EC%9D%B4%ED%81%B4%EB%9E%98%EC%8A%A4">
#             #원데이클래스
#            </a>
#           </li>
#          </ul>
#         </div>
#        </section>
#        <!-- Event Pick -->
#        <section class="section_event_pick">
#         <div class="title_area">
#          <h1 class="title">
#           Event
#           <span class="text_normal">
#            Pick
#           </span>
#           <a class="btn_more" href="/prom/invitation">
#            더보기
#           </a>
#          </h1>
#         </div>
#         <div class="content_wrap wide_max_width_area">
#          <div class="pick_list">
#           <li class="pick_list_item">
#            <a data-c="adfab8fa1" href="/cs/a/44671?url=%2Fevent%2F183283" style="background-image: url('https://cfile1.onoffmix.com/images/event/183283/s')" target="_blank" title="[초대] 달달한 로맨스와 배꼽잡을 웃음 200% 유발! '연애하기 좋은 날'">
#             <span>
#              모임 타이틀이 들어가게 해주세요.
#             </span>
#            </a>
#           </li>
#           <li class="pick_list_item">
#            <a data-c="adfab8fa2" href="/cs/a/45038?url=%2Fevent%2F184462" style="background-image: url('https://cfile1.onoffmix.com/images/event/184462/s')" target="_blank" title="[초대] 달콤하고 짠맛나는 사랑 이야기! '운빨로맨스' ">
#             <span>
#              모임 타이틀이 들어가게 해주세요.
#             </span>
#            </a>
#           </li>
#           <li class="pick_list_item">
#            <a data-c="adfab8fa3" href="/cs/a/44478?url=%2Fevent%2F182357" style="background-image: url('https://cfile1.onoffmix.com/images/event/182357/s')" target="_blank" title="[초대] '약물중독' 그 후의 진짜 이야기! '각인'">
#             <span>
#              모임 타이틀이 들어가게 해주세요.
#             </span>
#            </a>
#           </li>
#           <li class="pick_list_item">
#            <a data-c="adfab8fa4" href="/cs/a/45173?url=%2Fevent%2F185148" style="background-image: url('https://cfile1.onoffmix.com/images/event/185148/s')" target="_blank" title="[초대] 관객이 직접 뽑는 서바이벌 개그쇼! '개그 프로듀스 18'">
#             <span>
#              모임 타이틀이 들어가게 해주세요.
#             </span>
#            </a>
#           </li>
#           <li class="pick_list_item">
#            <a data-c="adfab8fa5" href="/cs/a/44773?url=%2Fevent%2F183531" style="background-image: url('https://cfile1.onoffmix.com/images/event/183531/s')" target="_blank" title="[초대] 공연장으로 떠나는 신나는 캠핑! 가족 뮤지컬 '아빠! 캠핑가요!'">
#             <span>
#              모임 타이틀이 들어가게 해주세요.
#             </span>
#            </a>
#           </li>
#          </div>
#         </div>
#        </section>
#        <!-- 한번 더! Check -->
#        <section class="section_more_check">
#         <div class="title_area">
#          <h1 class="title">
#           한번 더!
#           <span class="text_spacing-0">
#            Check
#           </span>
#          </h1>
#         </div>
#         <div class="content_wrap wide_max_width_area">
#          <!-- 최소6구좌, 최대12구좌 -->
#          <div class="banner_more_check owl-carousel">
#           <a data-c="bottom1" href="/cs/a/44973?url=%2Fevent%2F183862" target="_blank" title="상장예정기업투자 정규 입문특강 ★ 20배 수익 나는 기업 찾는법 ★">
#            <img alt="상장예정기업투자 정규 입문특강 ★ 20배 수익 나는 기업 찾는법 ★" src="https://cfile1.onoffmix.com/attach/bWf2rtYH9gv84yV01ZBdO3MCRF7cmplP"/>
#           </a>
#           <a data-c="bottom2" href="/cs/a/45169?url=%2Fevent%2F183770" target="_blank" title="【해외취업 이민영어】는 달라야한다 -나없이 해외취업 가지마라 편">
#            <img alt="【해외취업 이민영어】는 달라야한다 -나없이 해외취업 가지마라 편" src="https://cfile1.onoffmix.com/images/event/183770/s"/>
#           </a>
#           <a data-c="bottom3" href="/cs/a/45018?url=%2Fevent%2F184430" target="_blank" title="2019 부산국제광고제">
#            <img alt="2019 부산국제광고제" src="https://cfile1.onoffmix.com/images/event/184430/s"/>
#           </a>
#           <a data-c="bottom4" href="/cs/a/44994?url=%2Fevent%2F184436" target="_blank" title="경기도 온라인 강사되기 프로젝트">
#            <img alt="경기도 온라인 강사되기 프로젝트" src="https://cfile1.onoffmix.com/images/event/184436/s"/>
#           </a>
#           <a data-c="bottom5" href="/cs/a/44940?url=%2Fevent%2F184334" target="_blank" title="2019년 제4회 빅데이터 신산업 스타트업 콘테스트">
#            <img alt="2019년 제4회 빅데이터 신산업 스타트업 콘테스트" src="https://cfile1.onoffmix.com/images/event/184334/s"/>
#           </a>
#           <a data-c="bottom6" href="/cs/a/45091?url=%2Fevent%2F180568" target="_blank" title="스탠포드형 놀이교육 전문가 과정 초급">
#            <img alt="스탠포드형 놀이교육 전문가 과정 초급" src="https://cfile1.onoffmix.com/images/event/180568/s"/>
#           </a>
#           <a data-c="bottom7" href="/cs/a/44735?url=%2Fevent%2F183418" target="_blank" title="2019 Akamai Security Summit Seoul">
#            <img alt="2019 Akamai Security Summit Seoul" src="https://cfile1.onoffmix.com/images/event/183418/s"/>
#           </a>
#           <a data-c="bottom8" href="/cs/a/45126?url=%2Fevent%2F184468" target="_blank" title="다함께 게임문화TALK!!(서울)">
#            <img alt="다함께 게임문화TALK!!(서울)" src="https://cfile1.onoffmix.com/images/event/184468/s"/>
#           </a>
#           <a data-c="bottom9" href="/cs/a/44726?url=%2Fevent%2F183179" target="_blank" title="(예비)창업자를 위한 지식재산(특허) 창업교육">
#            <img alt="(예비)창업자를 위한 지식재산(특허) 창업교육" src="https://cfile1.onoffmix.com/images/event/183179/s"/>
#           </a>
#           <a data-c="bottom10" href="/cs/a/45094?url=%2Fevent%2F183704" target="_blank" title="블록아이 카이스 콜라보 기념/ 디지털자산 전문트레이더 양성과정 / 코인, 블록체인, 암호화폐, 트레이더, 블록아이,">
#            <img alt="블록아이 카이스 콜라보 기념/ 디지털자산 전문트레이더 양성과정 / 코인, 블록체인, 암호화폐, 트레이더, 블록아이," src="https://cfile1.onoffmix.com/images/event/183704/s"/>
#           </a>
#           <a data-c="bottom11" href="/cs/a/44921?url=%2Fevent%2F184130" target="_blank" title="LG유플러스 5G 이노베이션 랩 참여업체모집 (상시모집)">
#            <img alt="LG유플러스 5G 이노베이션 랩 참여업체모집 (상시모집)" src="https://cfile1.onoffmix.com/images/event/184130/s"/>
#           </a>
#           <a data-c="bottom12" href="/cs/a/44911?url=%2Fevent%2F182115" target="_blank" title="[창업경진대회] Urban Innovation Challenge: Citypreneurs Seoul 2019">
#            <img alt="[창업경진대회] Urban Innovation Challenge: Citypreneurs Seoul 2019" src="https://cfile1.onoffmix.com/images/event/182115/s"/>
#           </a>
#          </div>
#         </div>
#        </section>
#        <!-- notice news / service guide link -->
#        <div class="bottom_section">
#         <div class="content_wrap wide_max_width_area">
#          <section class="section_notice_news">
#           <h1 class="notice_title">
#            공지사항
#           </h1>
#           <ul class="notice_content">
#            <li class="list_item">
#             <a href="/cs/a/44296?url=https%3A%2F%2Fonoffmix.com%2Fcs%2Fnotice%2F401" target="_blank" title="[업데이트] 온오프믹스 본인 인증 절차 업데이트 완료 안내드립니다.">
#              [업데이트] 온오프믹스 본인 인증 절차 업데이트 완료 안내드립니다.
#             </a>
#            </li>
#            <li class="list_item">
#             <a href="/cs/a/43986?url=https%3A%2F%2Fonoffmix.com%2Fcs%2Fnotice%2F398" target="_blank" title="[업데이트] 온오프믹스 뉴스레터 업데이트 안내입니다.">
#              [업데이트] 온오프믹스 뉴스레터 업데이트 안내입니다.
#             </a>
#            </li>
#           </ul>
#           <a class="btn_more" href="/cs/notice">
#            더보기
#            <span>
#             &gt;
#            </span>
#           </a>
#          </section>
#          <section class="section_sevice_guide">
#           <ul class="guide_list">
#            <li class="list_item place">
#             <a href="https://place.onoffmix.com/" target="_blank">
#              플레이스
#             </a>
#            </li>
#            <li class="list_item howto">
#             <a href="/service/guide/eventCreate/howto" target="_blank">
#              개설/신청방법
#             </a>
#            </li>
#            <li class="list_item product_info">
#             <a href="/service/advert/product/guide" target="_blank">
#              광고상품안내
#             </a>
#            </li>
#            <li class="list_item alliance">
#             <a href="/service/advert/product/partner" target="_blank">
#              제휴서비스
#             </a>
#            </li>
#            <li class="list_item gifticon">
#             <a href="/service/advert/product/partner?gifticon" target="_blank">
#              기프티콘
#             </a>
#            </li>
#            <li class="list_item faq">
#             <a href="/cs/faq">
#              FAQ
#             </a>
#            </li>
#           </ul>
#          </section>
#         </div>
#        </div>
#        <!-- =================================== Main End =================================== -->
#        <!-- =================================== Footer Start =================================== -->
#        <footer class="footer_wrap" id="footer">
#         <div class="information_area wide_max_width_area">
#          <ul class="company_sns">
#           <li class="list_item onoffmix">
#            <a href="http://apps.onoffmix.com" target="_blank" title="온오프믹스 앱 소개">
#             onoffmix
#            </a>
#           </li>
#           <li class="list_item youtube">
#            <a href="https://www.youtube.com/channel/UC2W4gjEfJBaEheQ1vwACVTg" target="_blank" title="온오프믹스 유튜브">
#             youtube
#            </a>
#           </li>
#           <li class="list_item instagram">
#            <a href="https://www.instagram.com/onoffmix" target="_blank" title="온오프믹스 인스타그램">
#             instagram
#            </a>
#           </li>
#           <li class="list_item facebook">
#            <a href="https://www.facebook.com/onoffmix" target="_blank" title="온오프믹스 페이스북">
#             facebook
#            </a>
#           </li>
#           <li class="list_item naver">
#            <a href="https://blog.naver.com/onoffmix" target="_blank" title="온오프믹스 네이버블로그">
#             naver blog
#            </a>
#           </li>
#          </ul>
#          <ul class="company_links info_lists">
#           <li class="list_item">
#            <a href="http://corp.onoffmix.com/" target="_blank">
#             회사소개
#            </a>
#           </li>
#           <li class="list_item">
#            <a href="https://onoffmix.com/legal/agreement" target="_blank">
#             서비스약관 및 정책
#            </a>
#           </li>
#           <li class="list_item">
#            <a href="https://onoffmix.com/legal/privacy" target="_blank">
#             <strong>
#              개인정보취급방침
#             </strong>
#            </a>
#           </li>
#           <li class="list_item">
#            <a href="/service/advert/product/guide" target="_blank">
#             광고문의
#            </a>
#           </li>
#           <li class="list_item">
#            <a href="/ir/main" target="_blank">
#             투자정보
#            </a>
#           </li>
#           <li class="list_item">
#            <a href="https://onoffmix.com/cs/inquire" target="_blank">
#             문의하기
#            </a>
#           </li>
#           <li class="list_item">
#            <a href="https://onoffmix.com/cs/suggest" target="_blank">
#             제안하기
#            </a>
#           </li>
#           <li class="list_item">
#            <a href="https://onoffmix.com/cs" target="_blank">
#             <strong>
#              고객센터
#             </strong>
#            </a>
#           </li>
#          </ul>
#          <ul class="company_info info_lists">
#           <li class="list_item">
#            (주) 온오프믹스 대표이사 양준철
#           </li>
#           <li class="list_item">
#            개인정보관리책임자 이승희
#           </li>
#           <li class="list_item">
#            사업자등록번호
#            <span calss="text_spacing-0">
#             221-81-34988
#            </span>
#           </li>
#           <li class="list_item">
#            통신판매업 신고번호 제
#            <span calss="text_spacing-0">
#             2015
#            </span>
#            -서울서초-
#            <span calss="text_spacing-0">
#             0928
#            </span>
#            호
#           </li>
#          </ul>
#          <ul class="company_contact info_lists">
#           <li class="list_item">
#            서울특별시 서초구 강남대로
#            <span calss="text_spacing-0">
#             79
#            </span>
#            길
#            <span calss="text_spacing-0">
#             59
#            </span>
#            새로나빌딩
#            <span calss="text_spacing-0">
#             3
#            </span>
#            층
#           </li>
#           <li class="list_item text_spacing-0">
#            Tel 02-6080-5579
#           </li>
#           <li class="list_item text_spacing-0">
#            Fax 02-6280-8089
#           </li>
#           <li class="list_item text_spacing-0">
#            Email :
#            <a class="email" href="mailto:webmaster@onoffmix.com">
#             webmaster@onoffmix.com
#            </a>
#           </li>
#          </ul>
#          <div class="company_bottom">
#           <p class="info_msg">
#            온오프믹스는 통신판매중개자이며 모임에 대한 당사자 및 주최자가 아닙니다. 따라서 온오프믹스는 등록된 모임에 대하여 책임을 지지 않습니다.
#           </p>
#           <p class="copyright text_spacing-0">
#            copyright © ONOFFMIX.COM, All Rights Reserved.
#           </p>
#          </div>
#         </div>
#        </footer>
#        <!-- =================================== Footer End =================================== -->
#        <!-- Plugin  -->
#        <script src="https://static.onoffmix.com/js/pc/dist/common/plugins/owl.carousel.min.js">
#        </script>
#        <!-- Script -->
#        <script src="https://static.onoffmix.com/js/pc/dist/common/common.js">
#        </script>
#        <script src="https://static.onoffmix.com/js/pc/dist/common/header.js">
#        </script>
#        <script src="https://static.onoffmix.com/js/pc/dist/main/sliderRotate.js">
#        </script>
#        <script src="https://static.onoffmix.com/js/pc/dist/main/main.js">
#        </script>
#        <script src="https://static.onoffmix.com/js/pc/dist/common/today-seen.js">
#        </script>
#        <!-- PC Common Script -->
#        <!-- <script src="https://static.onoffmix.com/js/pc/dist/common/common.js"></script>
#     <script src="https://static.onoffmix.com/js/pc/dist/common/header.js"></script> -->
#        <script src="https://static.onoffmix.com/js/common/dist/plugins/app/app-ver-chk.js">
#        </script>
#        <script src="https://static.onoffmix.com/js/common/dist/log/statistic.js">
#        </script>
#        <!-- Script -->
#        <script type="text/javascript">
#         window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"4d73c0dfa7","applicationID":"119983018","transactionName":"Z1MAZEVWDREHWkEMWl4ZI1NDXgwMSXZzKGpzWQxERVgPDgNLGjpHVVsDQA==","queueTime":0,"applicationTime":1057,"atts":"SxQDEg1MHh8=","errorBeacon":"bam.nr-data.net","agent":""}
#        </script>
#       </div>
#      </section>
#     </main>
#    </div>
#   </header>
#  </body>
# </html>

# %% [markdown]
# # 한글이 깨지는 경우
# - 인코딩 처리

# %%
import requests
from bs4 import BeautifulSoup
# 대법원 사이트
url = 'http://scourt.go.kr/scourt/index.html'
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
bs = BeautifulSoup(res.text, 'lxml')
bs.title.string
# Out:
# '´ëÇÑ¹Î±¹ ¹ý¿ø'

# %%
res.encoding
# Out:
# 'ISO-8859-1'

# %% [markdown]
# ## requests의 인코딩 처리
#
# - 인코딩을 자동 인식하나 가끔 부정확
#     - 대부분 html 문서상 설정이 잘못된 경우가 많다.
# - 대법원 사이트의 경우 EUC-KR을 ISO-8859-1로 오인식
#     - 대법원 사이트는 EUC-KR로 만들긴 했는데 잘못만 들어져서 파이썬이 ISO-8859-1로 인식한다. (charset=euc-kr 로 되있는데 음..)
# - ISO-8859-1은 서유럽 언어(프랑스, 독일등)를 위한 유니코드 이전 국제표준(Latin-1)
#
#
# ## 인코딩 바꾸기
#
# - 인코딩 값을 바꿔주면 됨
# - 국내 사이트의 경우 `euc-kr`과 `utf8` 둘 중에 하나이므로 하나씩 시도 (현재는 UTF-8로 설정하는 추세)
#   - UTF-8: 유니코드라는 국제 표준의 한 형식 (해외 표준)
#   - EUC-KR: 완성형 국내 표준 (1989년 국내에서 정한 내부 표준)

# %%
# 인코딩 변경
res.encoding = 'UTF-8'
bs = BeautifulSoup(res.text, 'lxml')
bs.title.string
# Out:
# '���ѹα� ����'

# %%
res.encoding = 'EUC-KR'
bs = BeautifulSoup(res.text, 'lxml')
bs.title.string
# Out:
# '대한민국 법원'
